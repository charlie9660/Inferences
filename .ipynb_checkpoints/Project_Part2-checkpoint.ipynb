# %%
# %pylab
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import seaborn as sns
sns.set()
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os.path
import scipy as sp
import scipy.stats
import statsmodels as smr
import statsmodels.stats.api as sms
import statsmodels.api as sm
import statsmodels.formula.api as smf
scipy.stats.chisqprob = lambda chisq, df: scipy.stats.chi2.sf(chisq, df)

# %%
class Project:   
    def __init__(self):
        self.data = None
        self.train_data = None
        self.test_data = None
            
    def _load_data_(self,filepath):
      
        #if (~os.path.isfile('train.csv')) | (~os.path.isfile('test.csv')):
           # self.data = pd.read_csv(filepath,encoding='ISO-8859-1')
           # self.train_test_split()
           # self._write_data_()
            
        self.train_data = pd.read_csv('train.csv')
                                #,encoding='ISO-8859-1')
        self.test_data = pd.read_csv('test.csv',encoding='ISO-8859-1')
        return self.train_data
        
    def _write_data_(self):
        self.train_data.to_csv('train.csv')
        self.test_data.to_csv('test.csv')
    
    def train_test_split(self):
        self.train_data, self.test_data = train_test_split(self.data, test_size=0.2, random_state=42)   
        
    def null_summary(self,df):
        print(df.isnull().sum())
        all_data_na = (df.isnull().sum() / len(df)) * 100
        all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
        missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
        missing_data.head()
        if missing_data.size> 0:
            f, ax = plt.subplots(figsize=(15, 12))
            plt.xticks(rotation='90')
            sns.barplot(x=all_data_na.index, y=all_data_na)
            plt.xlabel('Features', fontsize=15)
            plt.ylabel('Percent of missing values', fontsize=15)
            plt.title('Percent missing data by feature', fontsize=15)
            plt.show()
            
    def get_stats(self,df,variable):
        print("Skewness: %f" % df[variable].skew())
        print("Kurtosis: %f" % df[variable].kurt())
        print("Mean: %f" % df[variable].mean())
        print("Variance: %f" % (df[variable].var()))

            
    def correlation_map(self,df,outcome,k):
        corrmat = df.corr()
        col_large = corrmat.nlargest(k+1,outcome)[outcome].index
        col_small = corrmat.nsmallest(k,outcome)[outcome].index
        cols = col_large.union(col_small)
        cm = np.corrcoef(corrmat[cols].loc[cols].values.T)
        print(corrmat[cols].loc[outcome])
        #sns.set(font_scale=1.25)
        hm = sns.heatmap(cm, cbar=True, vmax=1,annot=True, fmt='.1f', annot_kws={'size': 8}, yticklabels=cols.values, xticklabels=cols.values)
        return cols
    
    def encode_organization(self,x):
            if 'Academy' in x:
                return 1
            elif 'Instituion' in x:
                return 2
            elif 'College' in x:
                return 3
            elif 'University' in x:
                return 4
            else:
                return 0
    
    def encode_cost(self,df):
        prices = []
        for i in range(len(df)):
            if pd.notnull(df['NPT4_PUB'][i]):
                prices.append(df['NPT4_PUB'][i])
            elif pd.notnull(df['NPT4_PRIV'][i]):
                prices.append(df['NPT4_PRIV'][i])
            else:
                prices.append(np.NaN) 
        
        df.loc[:,'NET_COST'] = pd.Series(prices, index=df.index)
        
        return df
    
    def encode_25KBinary(self, df):
        vals = []
        for i in range(len(df)):
            if float(df['gt_25k_p6'][i]) >= 0.6:
                vals.append(1)
            elif float(df['gt_25k_p6'][i]) < 0.6:
                vals.append(0)
            else:
                vals.append(np.NaN)
        
        df.loc[:,'Binary_25k'] = pd.Series(vals, index=df.index)
        
        return df
    
    def encode_state(self,x):
        west = ['WA','MT','OR','ID','WT','CA','NV','UT','CO','AZ','NM']
        midwest = ['ND','MN','SD','NE','KS','IA','MO','WI','IL','MI','IN','OH','WY']
        northeast = ['NY','PA','NJ','RI','CT','MA','VT','NH','ME']
        south = ['TX','OK','AR','LA','MS','AL','GA','TN','KY','WV','DC','MD','VA','DE','NC','SC','FL']
        others =['AK','HI','PR','PW','AS','GU','FM','VI']
        
        if x in others:
            return 0
        elif x in midwest:
            return 1
        elif x in south:
            return 2
        elif x in west:
            return 3
        elif x in northeast:
            return 4
        else: return x

# %%
project = Project()
project._load_data_('train.csv')
# Out:
#       Unnamed: 0                                             INSTNM  \
# 0           7440       Marian Health Careers Center-Van Nuys Campus
# 1           5144                   Emma's Beauty Academy-Juana Diaz
# 2           7169                              Milan Institute-Nampa
# 3           5160              University of Phoenix-Bay Area Campus
# 4           4987                      Sanford-Brown Institute-Tampa
# 5           2415                  Truckee Meadows Community College
# 6           6076                             Healing Arts Institute
# 7           1790          Maryland University of Integrative Health
# 8           7170             Milan Institute of Cosmetology-El Paso
# 9           3857                  Middle Tennessee State University
# 10          3260           Virginia Marti College of Art and Design
# 11          3817                                Lipscomb University
# 12          1670                           McNeese State University
# 13           904              Manhattan Hairstyling Academy - North
# 14          1446         La James International College-Cedar Falls
# 15          7317   National Personal Training Institute of Colorado
# 16          5865                  Eli Whitney Technical High School
# 17          7190                    Carolina College of Hair Design
# 18          6399                 Regency Beauty Institute-Mehlville
# 19          6816                         MediaTech Institute-Austin
# 20          1565          PJ's College of Cosmetology- Indianapolis
# 21          3617                        Beaver Falls Beauty Academy
# 22          2034                                 Oakland University
# 23          4102        Universal Technical Institute of Texas Inc.
# 24          4966  SW School of Business and Technical Careers-No...
# 25          4741                            Iverson Business School
# 26          3757                    South Carolina State University
# 27          3519                                     King's College
# 28          2288                    University of Missouri-St Louis
# 29          6753                             Skin Science Institute
# ...          ...                                                ...
# 6213        6420           Academy Di Capelli-School of Cosmetology
# 6214        5051            Northeastern Hospital School of Nursing
# 6215        5311              Albert I Prince Technical High School
# 6216        2433       New Hampshire Institute for Therapeutic Arts
# 6217        6949           Academy of Cosmetology and Esthetics NYC
# 6218        7581                                   Columbia College
# 6219        5611                      Florida Gulf Coast University
# 6220        2391                                 Peru State College
# 6221         769                              Quinnipiac University
# 6222        7476             Chamberlain College of Nursing-Georgia
# 6223        1685            Vanguard College of Cosmetology-Slidell
# 6224         130                            Hair Academy of Safford
# 6225        2919                  Davidson County Community College
# 6226        3171                         College of Mount St Joseph
# 6227        3444                                  Carlow University
# 6228        6231               ITT Technical Institute-Owings Mills
# 6229        5578           Ocean County Vocational-Technical School
# 6230        4426                       Medical College of Wisconsin
# 6231        5334                     Central College of Cosmetology
# 6232         466                 Marinello Schools of Beauty-Lomita
# 6233        6265                      Academy of Hair Design-Jasper
# 6234        5734                         Everest College-Chesapeake
# 6235        3092   Cincinnati State Technical and Community College
# 6236        3772                         Black Hills Beauty College
# 6237        5191             Capri Institute of Hair Design-Paramus
# 6238        5226                                South Texas College
# 6239        5390               Quality Technical and Beauty College
# 6240         860                         Fort Pierce Beauty Academy
# 6241        7603                               Digital Film Academy
# 6242        7270                              Aveda Institute-Boise
#
#                   CITY STABBR  PREDDEG  CONTROL  LOCALE  SATVRMID  SATMTMID  \
# 0             Van Nuys     CA        1        3    11.0       NaN       NaN
# 1           Juana Diaz     PR        1        3    23.0       NaN       NaN
# 2                Nampa     ID        1        3    22.0       NaN       NaN
# 3             San Jose     CA        3        3    11.0       NaN       NaN
# 4                Tampa     FL        1        3    21.0       NaN       NaN
# 5                 Reno     NV        2        1    12.0       NaN       NaN
# 6           Perrysburg     OH        1        3    21.0       NaN       NaN
# 7               Laurel     MD        4        2    21.0       NaN       NaN
# 8              El Paso     TX        1        3    11.0       NaN       NaN
# 9         Murfreesboro     TN        3        1    12.0     515.0     510.0
# 10            Lakewood     OH        2        3    21.0       NaN       NaN
# 11           Nashville     TN        3        2    11.0     585.0     580.0
# 12        Lake Charles     LA        3        1    13.0     500.0     525.0
# 13               Tampa     FL        0        3     NaN       NaN       NaN
# 14         Cedar Falls     IA        1        3    13.0       NaN       NaN
# 15    Colorado Springs     CO        1        3    11.0       NaN       NaN
# 16              Hamden     CT        1        1    21.0       NaN       NaN
# 17           Asheville     NC        1        3    13.0       NaN       NaN
# 18           Mehlville     MO        1        3    21.0       NaN       NaN
# 19              Austin     TX        1        3    11.0       NaN       NaN
# 20        Indianapolis     IN        0        3     NaN       NaN       NaN
# 21        Beaver Falls     PA        1        3    21.0       NaN       NaN
# 22     Rochester Hills     MI        3        1    21.0       NaN       NaN
# 23             Houston     TX        1        3    11.0       NaN       NaN
# 24              Austin     TX        0        3     NaN       NaN       NaN
# 25           Arlington     TX        1        3    11.0       NaN       NaN
# 26          Orangeburg     SC        3        1    32.0     408.0     431.0
# 27        Wilkes-Barre     PA        3        2    13.0       NaN       NaN
# 28         Saint Louis     MO        3        1    21.0       NaN     550.0
# 29      Salt Lake City     UT        1        3    12.0       NaN       NaN
# ...                ...    ...      ...      ...     ...       ...       ...
# 6213       Wallingford     CT        1        3    21.0       NaN       NaN
# 6214      Philadelphia     PA        1        2    11.0       NaN       NaN
# 6215          Hartford     CT        1        1    12.0       NaN       NaN
# 6216          Bridgton     ME        0        3     NaN       NaN       NaN
# 6217     Staten Island     NY        1        3    11.0       NaN       NaN
# 6218       Centreville     VA        1        3    21.0       NaN       NaN
# 6219        Fort Myers     FL        3        1    21.0     510.0     510.0
# 6220              Peru     NE        3        1    42.0       NaN       NaN
# 6221            Hamden     CT        3        2    21.0     535.0     560.0
# 6222           Atlanta     GA        0        3    13.0       NaN       NaN
# 6223           Slidell     LA        1        3    23.0       NaN       NaN
# 6224           Safford     AZ        1        3    41.0       NaN       NaN
# 6225       Thomasville     NC        1        1    41.0       NaN       NaN
# 6226        Cincinnati     OH        3        2    21.0     460.0     465.0
# 6227        Pittsburgh     PA        3        2    11.0     480.0     465.0
# 6228      Owings Mills     MD        2        3    21.0       NaN       NaN
# 6229        Toms River     NJ        1        1    21.0       NaN       NaN
# 6230         Milwaukee     WI        4        2    21.0       NaN       NaN
# 6231      Saint Robert     MO        1        3    41.0       NaN       NaN
# 6232            Lomita     CA        0        3     NaN       NaN       NaN
# 6233            Jasper     TX        1        3    33.0       NaN       NaN
# 6234        Chesapeake     VA        1        3    21.0       NaN       NaN
# 6235        Cincinnati     OH        2        1    11.0       NaN       NaN
# 6236        Rapid City     SD        1        3    13.0       NaN       NaN
# 6237           Paramus     NJ        1        3    21.0       NaN       NaN
# 6238           McAllen     TX        2        1    12.0       NaN       NaN
# 6239           Bayamon     PR        1        3    21.0       NaN       NaN
# 6240       Fort Pierce     FL        1        3    21.0       NaN       NaN
# 6241          New York     NY        1        3    11.0       NaN       NaN
# 6242             Boise     ID        1        3    12.0       NaN       NaN
#
#       SATWRMID        ...          RET_PTL4  PCTFLOAN  UG25abv  \
# 0          NaN        ...               NaN    0.6786   0.5745
# 1          NaN        ...               NaN    0.0000   0.1733
# 2          NaN        ...               NaN    0.4332   0.4314
# 3          NaN        ...               NaN    0.6299   0.8464
# 4          NaN        ...               NaN    0.6094   0.4858
# 5          NaN        ...            0.4680    0.1438   0.3980
# 6          NaN        ...               NaN    0.6197   0.6250
# 7          NaN        ...               NaN       NaN      NaN
# 8          NaN        ...               NaN    0.4466   0.4847
# 9          NaN        ...               NaN    0.5732   0.2315
# 10         NaN        ...               NaN    0.7340   0.2890
# 11         NaN        ...               NaN    0.5766   0.1460
# 12         NaN        ...               NaN    0.4129   0.2107
# 13         NaN        ...               NaN       NaN      NaN
# 14         NaN        ...               NaN    0.8039   0.3043
# 15         NaN        ...               NaN    0.3636   0.6282
# 16         NaN        ...               NaN    0.0000   0.8293
# 17         NaN        ...               NaN    0.0000   0.3559
# 18         NaN        ...               NaN    0.7938   0.1628
# 19         NaN        ...               NaN    0.7132   0.3218
# 20         NaN        ...               NaN       NaN      NaN
# 21         NaN        ...               NaN    0.7627   0.3673
# 22         NaN        ...               NaN    0.3689   0.2060
# 23         NaN        ...               NaN    0.5981   0.2556
# 24         NaN        ...               NaN       NaN      NaN
# 25         NaN        ...               NaN    0.0000   1.0000
# 26         NaN        ...               NaN    0.8187   0.1015
# 27         NaN        ...               NaN    0.7660   0.0560
# 28         NaN        ...               NaN    0.4279   0.2776
# 29         NaN        ...            1.0000    0.2390   0.5821
# ...        ...        ...               ...       ...      ...
# 6213       NaN        ...            0.8333    0.8025   0.1379
# 6214       NaN        ...               NaN    0.8243   0.6250
# 6215       NaN        ...               NaN    0.0000   0.7636
# 6216       NaN        ...               NaN       NaN      NaN
# 6217       NaN        ...            0.7500    0.5673   0.2462
# 6218       NaN        ...            0.8000    0.0310   0.9116
# 6219     500.0        ...               NaN    0.4679   0.1352
# 6220       NaN        ...               NaN    0.4704   0.2813
# 6221     545.0        ...               NaN    0.6188   0.0271
# 6222       NaN        ...               NaN    0.9396   0.7488
# 6223       NaN        ...               NaN    0.6941   0.1776
# 6224       NaN        ...               NaN    0.1957   0.2500
# 6225       NaN        ...            0.4724    0.5005   0.4611
# 6226       NaN        ...               NaN    0.6543   0.2546
# 6227     470.0        ...               NaN    0.6302   0.2424
# 6228       NaN        ...               NaN    0.8623   0.7240
# 6229       NaN        ...               NaN    0.2426   0.2893
# 6230       NaN        ...               NaN       NaN      NaN
# 6231       NaN        ...               NaN    0.0000   0.4667
# 6232       NaN        ...               NaN       NaN      NaN
# 6233       NaN        ...            0.1538    0.0508   0.0877
# 6234       NaN        ...            0.6667    0.4869   0.5762
# 6235       NaN        ...            0.3843    0.1396   0.4892
# 6236       NaN        ...               NaN    0.4231   0.1339
# 6237       NaN        ...            0.8333    0.3520   0.2741
# 6238       NaN        ...               NaN    0.0000   0.1823
# 6239       NaN        ...               NaN    0.0000   0.3511
# 6240       NaN        ...            0.5000    0.0000   0.3571
# 6241       NaN        ...               NaN    0.5714   0.5263
# 6242       NaN        ...               NaN    0.5057   0.2687
#
#       GRAD_DEBT_MDN_SUPP  GRAD_DEBT_MDN10YR_SUPP    RPY_3YR_RT_SUPP  \
# 0                  15680              174.080144        0.847161572
# 1                    NaN                     NaN  PrivacySuppressed
# 2                   9500              105.469475        0.351691581
# 3                  35500              394.122775        0.406534043
# 4                   9500              105.469475        0.409117821
# 5                  10000                111.0205        0.551597052
# 6                   7917             87.89492985        0.755102041
# 7      PrivacySuppressed       PrivacySuppressed  PrivacySuppressed
# 8                  14252             158.2264166        0.291276491
# 9                22170.5             246.1379995        0.739414441
# 10                 26320              292.205956        0.551111111
# 11                 22125             245.6328563        0.884946237
# 12                 21750             241.4695875        0.695116947
# 13                  9150             101.5837575        0.274528302
# 14                 12000                133.2246        0.608695652
# 15                  6333             70.30928265                NaN
# 16                   NaN                     NaN                NaN
# 17                   NaN                     NaN                NaN
# 18                 14144             157.0273952         0.47496977
# 19                  9500              105.469475        0.545977011
# 20                 10000                111.0205        0.303691275
# 21                  8800                97.69804        0.477777778
# 22                 25000               277.55125        0.772695773
# 23                 16813             186.6587667        0.600071672
# 24     PrivacySuppressed       PrivacySuppressed  PrivacySuppressed
# 25                  8179             90.80366695        0.204379562
# 26                 37000               410.77585        0.452402957
# 27                 27000               299.75535        0.879604672
# 28                 22000                244.2451        0.775217391
# 29               10685.5             118.6309553         0.64893617
# ...                  ...                     ...                ...
# 6213               13833             153.5746577        0.785714286
# 6214             22051.5             244.8168556             0.9375
# 6215                 NaN                     NaN                NaN
# 6216   PrivacySuppressed       PrivacySuppressed        0.866666667
# 6217                9500              105.469475  PrivacySuppressed
# 6218                4367             48.48265235  PrivacySuppressed
# 6219               18500              205.387925        0.822815534
# 6220               21282             236.2738281         0.76835443
# 6221               26000                288.6533        0.955575703
# 6222               25693             285.2449707        0.838268282
# 6223               16500              183.183825        0.505050505
# 6224   PrivacySuppressed       PrivacySuppressed        0.425925926
# 6225               12500              138.775625        0.549206349
# 6226               32000                355.2656        0.761904762
# 6227               27000               299.75535        0.810140237
# 6228             25833.5             286.8048087        0.394119686
# 6229                5725             63.55923625        0.751412429
# 6230                 NaN                     NaN  PrivacySuppressed
# 6231                 NaN                     NaN                NaN
# 6232               10555             117.1821378        0.350995234
# 6233                6333             70.30928265                NaN
# 6234                9500              105.469475        0.210248681
# 6235               17913             198.8710217        0.493448524
# 6236               11790             130.8931695                0.7
# 6237                6333             70.30928265        0.733990148
# 6238                 NaN                     NaN                NaN
# 6239                 NaN                     NaN                NaN
# 6240                 NaN                     NaN                NaN
# 6241                9500              105.469475                NaN
# 6242               12000                133.2246  PrivacySuppressed
#
#       C150_4_POOLED_SUPP  C200_L4_POOLED_SUPP    md_earn_wne_p10  \
# 0                    NaN           0.27471978              47500
# 1                    NaN          0.703098375              13400
# 2                    NaN                  NaN              16100
# 3            0.135344954                  NaN              53400
# 4                    NaN          0.596397059              28300
# 5                    NaN          0.203587983              32500
# 6                    NaN                  NaN                NaN
# 7                    NaN                  NaN                NaN
# 8                    NaN                  NaN              18900
# 9            0.453413673                  NaN              36100
# 10                   NaN          0.431179817              27700
# 11               0.60085                  NaN              39000
# 12           0.379528662                  NaN              36800
# 13                   NaN                  NaN              14400
# 14                   NaN               0.7389              18200
# 15                   NaN          0.756990654                NaN
# 16                   NaN          0.828847748  PrivacySuppressed
# 17                   NaN               0.8901                NaN
# 18                   NaN          0.521742609              19600
# 19                   NaN                  NaN                NaN
# 20                   NaN                  NaN              18200
# 21                   NaN          0.711153333  PrivacySuppressed
# 22           0.431533704                  NaN              42600
# 23                   NaN           0.57390375              40200
# 24                   NaN                  NaN              14600
# 25                   NaN          0.943557863              25400
# 26           0.351045606                  NaN              30400
# 27            0.66991607                  NaN              48900
# 28           0.461622388                  NaN              40400
# 29                   NaN               0.7619                NaN
# ...                  ...                  ...                ...
# 6213                 NaN          0.940452381                NaN
# 6214                 NaN                  NaN  PrivacySuppressed
# 6215                 NaN    PrivacySuppressed  PrivacySuppressed
# 6216                 NaN                  NaN  PrivacySuppressed
# 6217                 NaN          0.896575862                NaN
# 6218                 NaN                  NaN                NaN
# 6219         0.446422037                  NaN              41200
# 6220         0.374037406                  NaN              35800
# 6221         0.758448562                  NaN              56400
# 6222                 NaN                  NaN                NaN
# 6223                 NaN           0.74999717  PrivacySuppressed
# 6224                 NaN          0.897392308              12600
# 6225                 NaN          0.331691677              24400
# 6226         0.580756522                  NaN              39900
# 6227         0.585703905                  NaN              39900
# 6228         0.343129412                  NaN              38400
# 6229                 NaN          0.590011713              36000
# 6230                 NaN                  NaN             250000
# 6231                 NaN          0.587395105  PrivacySuppressed
# 6232                 NaN                  NaN                NaN
# 6233                 NaN          0.886784906              15000
# 6234                 NaN          0.656466207              23000
# 6235                 NaN          0.224769362              29700
# 6236                 NaN          0.739441212              17500
# 6237                 NaN          0.675253846              26000
# 6238         0.178058599                  NaN              29100
# 6239                 NaN              0.85805              14600
# 6240                 NaN          0.980788462              15500
# 6241                 NaN                  NaN                NaN
# 6242                 NaN                    1                NaN
#
#               gt_25k_p6
# 0           0.767567575
# 1           0.181818187
# 2           0.249343827
# 3           0.705231071
# 4           0.524061024
# 5           0.543252587
# 6     PrivacySuppressed
# 7                   NaN
# 8           0.228511527
# 9           0.592180908
# 10          0.512658238
# 11          0.670796454
# 12           0.58359623
# 13          0.240126386
# 14           0.32432431
# 15                  NaN
# 16    PrivacySuppressed
# 17                  NaN
# 18          0.333333343
# 19    PrivacySuppressed
# 20          0.179104477
# 21          0.242857143
# 22          0.647106767
# 23          0.678855062
# 24          0.096153848
# 25          0.315436244
# 26          0.392213404
# 27          0.740648389
# 28          0.687332571
# 29                  NaN
# ...                 ...
# 6213  PrivacySuppressed
# 6214  PrivacySuppressed
# 6215  PrivacySuppressed
# 6216        0.363636374
# 6217                NaN
# 6218                NaN
# 6219        0.704905093
# 6220        0.584269643
# 6221        0.827629149
# 6222                NaN
# 6223         0.24242425
# 6224  PrivacySuppressed
# 6225        0.386880845
# 6226        0.666115701
# 6227        0.649328887
# 6228        0.591855824
# 6229        0.540540516
# 6230                  1
# 6231        0.239999995
# 6232                NaN
# 6233        0.165517241
# 6234        0.303949237
# 6235         0.50870347
# 6236        0.208791211
# 6237           0.453125
# 6238        0.430688351
# 6239        0.126213595
# 6240        0.183856502
# 6241                NaN
# 6242                NaN
#
# [6243 rows x 43 columns]

# %%
df = project.train_data
df = df.drop(df.columns[0],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6243 entries, 0 to 6242
# Data columns (total 42 columns):
# INSTNM                    6243 non-null object
# CITY                      6243 non-null object
# STABBR                    6243 non-null object
# PREDDEG                   6243 non-null int64
# CONTROL                   6243 non-null int64
# LOCALE                    5911 non-null float64
# SATVRMID                  1036 non-null float64
# SATMTMID                  1048 non-null float64
# SATWRMID                  631 non-null float64
# ACTCMMID                  1076 non-null float64
# ACTENMID                  939 non-null float64
# ACTMTMID                  940 non-null float64
# ACTWRMID                  247 non-null float64
# SAT_AVG                   1136 non-null float64
# DISTANCEONLY              5913 non-null float64
# UGDS                      5680 non-null float64
# UGDS_WHITE                5680 non-null float64
# UGDS_BLACK                5680 non-null float64
# UGDS_HISP                 5680 non-null float64
# UGDS_ASIAN                5680 non-null float64
# UGDS_AIAN                 5680 non-null float64
# UGDS_NHPI                 5680 non-null float64
# UGDS_2MOR                 5680 non-null float64
# UGDS_NRA                  5680 non-null float64
# UGDS_UNKN                 5680 non-null float64
# PPTUG_EF                  5665 non-null float64
# NPT4_PUB                  1513 non-null float64
# NPT4_PRIV                 3832 non-null float64
# PCTPELL                   5658 non-null float64
# RET_FT4                   1876 non-null float64
# RET_FTL4                  3141 non-null float64
# RET_PT4                   1158 non-null float64
# RET_PTL4                  1831 non-null float64
# PCTFLOAN                  5658 non-null float64
# UG25abv                   5631 non-null float64
# GRAD_DEBT_MDN_SUPP        5683 non-null object
# GRAD_DEBT_MDN10YR_SUPP    5683 non-null object
# RPY_3YR_RT_SUPP           5479 non-null object
# C150_4_POOLED_SUPP        1979 non-null object
# C200_L4_POOLED_SUPP       3047 non-null object
# md_earn_wne_p10           5137 non-null object
# gt_25k_p6                 5354 non-null object
# dtypes: float64(30), int64(2), object(10)
# memory usage: 2.0+ MB

# %%
df.shape
# Out:
# (6243, 42)

# %%
df = df.apply(lambda x: x.replace('PrivacySuppressed',np.NAN))
df = project.encode_cost(df)
df = project.encode_25KBinary(df)

# %%
df['RPY_3YR_RT_SUPP'] = pd.to_numeric(df['RPY_3YR_RT_SUPP'])
df['md_earn_wne_p10'] = pd.to_numeric(df['md_earn_wne_p10'])
df['GRAD_DEBT_MDN_SUPP'] = pd.to_numeric(df['GRAD_DEBT_MDN_SUPP'])
df['GRAD_DEBT_MDN10YR_SUPP'] = pd.to_numeric(df['GRAD_DEBT_MDN10YR_SUPP'])
df['C150_4_POOLED_SUPP'] = pd.to_numeric(df['C150_4_POOLED_SUPP'])
df['C200_L4_POOLED_SUPP'] = pd.to_numeric(df['C200_L4_POOLED_SUPP'])

# %%
columns = df.columns
#drop outcomes variables and "name" variables 
treatment_variables = columns.drop(['INSTNM','CITY','STABBR','RPY_3YR_RT_SUPP', 'md_earn_wne_p10', 'gt_25k_p6', 'Binary_25k'])

# %%
#only keep the variables if less than 20% of the values are missing ( SHOULD I KEEP IT at 20%?)
keep_variables = []
for i in range(len(treatment_variables)):
    x = df[str(treatment_variables[i])].isnull().sum()/float((len(df)))
    if x <= 0.2:
        keep_variables.append(treatment_variables[i])

# %%
keep_variables
# Out:
# ['PREDDEG',
#  'CONTROL',
#  'LOCALE',
#  'DISTANCEONLY',
#  'UGDS',
#  'UGDS_WHITE',
#  'UGDS_BLACK',
#  'UGDS_HISP',
#  'UGDS_ASIAN',
#  'UGDS_AIAN',
#  'UGDS_NHPI',
#  'UGDS_2MOR',
#  'UGDS_NRA',
#  'UGDS_UNKN',
#  'PPTUG_EF',
#  'PCTPELL',
#  'PCTFLOAN',
#  'UG25abv',
#  'GRAD_DEBT_MDN_SUPP',
#  'GRAD_DEBT_MDN10YR_SUPP',
#  'NET_COST']

# %%
#correlations for RPY_3YR_RT_SUPP
for i in range(len(keep_variables)):
    print str(keep_variables[i])
    print df['RPY_3YR_RT_SUPP'].corr(df[str(keep_variables[i])])
# Out:
# PREDDEG
# 0.47481216846106106
# CONTROL
# -0.4352514428594318
# LOCALE
# 0.1230342150074187
# DISTANCEONLY
# -0.013832163764535338
# UGDS
# 0.20973050173732952
# UGDS_WHITE
# 0.4510994857770172
# UGDS_BLACK
# -0.49059804877949226
# UGDS_HISP
# -0.17259545227552947
# UGDS_ASIAN
# 0.2216831882798812
# UGDS_AIAN
# -0.07083112661172733
# UGDS_NHPI
# -0.030699245581573838
# UGDS_2MOR
# 0.08175865461545913
# UGDS_NRA
# 0.3613759353054309
# UGDS_UNKN
# -0.06653092251846349
# PPTUG_EF
# -0.07034291353156147
# PCTPELL
# -0.6536353764229733
# PCTFLOAN
# -0.13341299221258632
# UG25abv
# -0.5165301403484911
# GRAD_DEBT_MDN_SUPP
# 0.18086927111035483
# GRAD_DEBT_MDN10YR_SUPP
# 0.18086927109147896
# NET_COST
# 0.13124568331778796

# %%
#regressions for RPY_3YR_RT_SUPP
for i in range(len(keep_variables)):
    print (i)
    print (smf.ols('RPY_3YR_RT_SUPP ~ ' + str(keep_variables[i]), data=df).fit().summary())
# Out:
# 0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.225
# Model:                            OLS   Adj. R-squared:                  0.225
# Method:                 Least Squares   F-statistic:                     1468.
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          4.70e-282
# Time:                        23:30:14   Log-Likelihood:                 1464.7
# No. Observations:                5044   AIC:                            -2925.
# Df Residuals:                    5042   BIC:                            -2912.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4201      0.005     79.090      0.000       0.410       0.430
# PREDDEG        0.0996      0.003     38.309      0.000       0.094       0.105
# ==============================================================================
# Omnibus:                       86.685   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.764
# Skew:                          -0.183   Prob(JB):                     8.64e-15
# Kurtosis:                       2.583   Cond. No.                         5.08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.189
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     1178.
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          2.84e-232
# Time:                        23:30:14   Log-Likelihood:                 1350.1
# No. Observations:                5044   AIC:                            -2696.
# Df Residuals:                    5042   BIC:                            -2683.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8375      0.007    112.697      0.000       0.823       0.852
# CONTROL       -0.1064      0.003    -34.328      0.000      -0.113      -0.100
# ==============================================================================
# Omnibus:                      331.194   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              120.579
# Skew:                           0.069   Prob(JB):                     6.55e-27
# Kurtosis:                       2.255   Cond. No.                         7.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     72.79
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           1.91e-17
# Time:                        23:30:14   Log-Likelihood:                 794.27
# No. Observations:                4738   AIC:                            -1585.
# Df Residuals:                    4736   BIC:                            -1572.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5507      0.007     78.737      0.000       0.537       0.564
# LOCALE         0.0028      0.000      8.532      0.000       0.002       0.003
# ==============================================================================
# Omnibus:                      866.822   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              182.519
# Skew:                           0.034   Prob(JB):                     2.33e-40
# Kurtosis:                       2.041   Cond. No.                         50.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9063
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):              0.341
# Time:                        23:30:14   Log-Likelihood:                 758.58
# No. Observations:                4738   AIC:                            -1513.
# Df Residuals:                    4736   BIC:                            -1500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.6049      0.003    201.429      0.000       0.599       0.611
# DISTANCEONLY    -0.0420      0.044     -0.952      0.341      -0.128       0.044
# ==============================================================================
# Omnibus:                     1049.605   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              196.043
# Skew:                          -0.016   Prob(JB):                     2.69e-43
# Kurtosis:                       2.004   Cond. No.                         14.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 4
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     216.8
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           5.07e-48
# Time:                        23:30:14   Log-Likelihood:                 870.67
# No. Observations:                4715   AIC:                            -1737.
# Df Residuals:                    4713   BIC:                            -1724.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5824      0.003    178.293      0.000       0.576       0.589
# UGDS        8.068e-06   5.48e-07     14.726      0.000    6.99e-06    9.14e-06
# ==============================================================================
# Omnibus:                      692.896   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.887
# Skew:                           0.014   Prob(JB):                     1.57e-36
# Kurtosis:                       2.084   Cond. No.                     6.65e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 5
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.203
# Model:                            OLS   Adj. R-squared:                  0.203
# Method:                 Least Squares   F-statistic:                     1204.
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          3.69e-235
# Time:                        23:30:14   Log-Likelihood:                 1301.0
# No. Observations:                4715   AIC:                            -2598.
# Df Residuals:                    4713   BIC:                            -2585.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4250      0.006     73.255      0.000       0.414       0.436
# UGDS_WHITE     0.3418      0.010     34.700      0.000       0.323       0.361
# ==============================================================================
# Omnibus:                      154.481   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.383
# Skew:                          -0.036   Prob(JB):                     1.92e-16
# Kurtosis:                       2.397   Cond. No.                         4.75
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     1494.
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          3.86e-284
# Time:                        23:30:14   Log-Likelihood:                 1413.7
# No. Observations:                4715   AIC:                            -2823.
# Df Residuals:                    4713   BIC:                            -2811.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6936      0.003    198.281      0.000       0.687       0.700
# UGDS_BLACK    -0.4707      0.012    -38.651      0.000      -0.495      -0.447
# ==============================================================================
# Omnibus:                      377.663   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              141.550
# Skew:                          -0.172   Prob(JB):                     1.83e-31
# Kurtosis:                       2.224   Cond. No.                         4.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 7
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     144.7
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           7.50e-33
# Time:                        23:30:14   Log-Likelihood:                 835.91
# No. Observations:                4715   AIC:                            -1668.
# Df Residuals:                    4713   BIC:                            -1655.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6304      0.004    170.452      0.000       0.623       0.638
# UGDS_HISP     -0.1815      0.015    -12.029      0.000      -0.211      -0.152
# ==============================================================================
# Omnibus:                      724.425   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.405
# Skew:                          -0.087   Prob(JB):                     2.22e-38
# Kurtosis:                       2.077   Cond. No.                         5.23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     243.6
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           1.40e-53
# Time:                        23:30:15   Log-Likelihood:                 883.42
# No. Observations:                4715   AIC:                            -1763.
# Df Residuals:                    4713   BIC:                            -1750.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5781      0.003    172.573      0.000       0.572       0.585
# UGDS_ASIAN     0.8334      0.053     15.607      0.000       0.729       0.938
# ==============================================================================
# Omnibus:                      504.770   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              143.955
# Skew:                          -0.052   Prob(JB):                     5.50e-32
# Kurtosis:                       2.150   Cond. No.                         18.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 9
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     23.76
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           1.12e-06
# Time:                        23:30:15   Log-Likelihood:                 776.47
# No. Observations:                4715   AIC:                            -1549.
# Df Residuals:                    4713   BIC:                            -1536.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6076      0.003    196.077      0.000       0.602       0.614
# UGDS_AIAN     -0.4313      0.088     -4.875      0.000      -0.605      -0.258
# ==============================================================================
# Omnibus:                     1032.204   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              194.405
# Skew:                          -0.022   Prob(JB):                     6.10e-43
# Kurtosis:                       2.006   Cond. No.                         29.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 10
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     4.446
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):             0.0350
# Time:                        23:30:15   Log-Likelihood:                 766.84
# No. Observations:                4715   AIC:                            -1530.
# Df Residuals:                    4713   BIC:                            -1517.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6050      0.003    197.528      0.000       0.599       0.611
# UGDS_NHPI     -0.3652      0.173     -2.109      0.035      -0.705      -0.026
# ==============================================================================
# Omnibus:                     1002.758   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              192.092
# Skew:                          -0.016   Prob(JB):                     1.94e-42
# Kurtosis:                       2.012   Cond. No.                         57.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 11
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     31.72
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           1.89e-08
# Time:                        23:30:15   Log-Likelihood:                 780.43
# No. Observations:                4715   AIC:                            -1557.
# Df Residuals:                    4713   BIC:                            -1544.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5895      0.004    151.290      0.000       0.582       0.597
# UGDS_2MOR      0.5958      0.106      5.632      0.000       0.388       0.803
# ==============================================================================
# Omnibus:                     1177.935   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              203.736
# Skew:                          -0.004   Prob(JB):                     5.75e-45
# Kurtosis:                       1.982   Cond. No.                         35.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 12
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     707.9
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          1.93e-145
# Time:                        23:30:15   Log-Likelihood:                 1094.5
# No. Observations:                4715   AIC:                            -2185.
# Df Residuals:                    4713   BIC:                            -2172.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5735      0.003    190.155      0.000       0.568       0.579
# UGDS_NRA       2.1668      0.081     26.607      0.000       2.007       2.326
# ==============================================================================
# Omnibus:                      245.412   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.359
# Skew:                          -0.086   Prob(JB):                     1.61e-22
# Kurtosis:                       2.306   Cond. No.                         29.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 13
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     20.95
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           4.82e-06
# Time:                        23:30:15   Log-Likelihood:                 775.07
# No. Observations:                4715   AIC:                            -1546.
# Df Residuals:                    4713   BIC:                            -1533.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6108      0.003    181.214      0.000       0.604       0.617
# UGDS_UNKN     -0.1243      0.027     -4.578      0.000      -0.178      -0.071
# ==============================================================================
# Omnibus:                      831.912   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              178.812
# Skew:                          -0.030   Prob(JB):                     1.48e-39
# Kurtosis:                       2.048   Cond. No.                         9.11
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 14
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     23.43
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           1.34e-06
# Time:                        23:30:15   Log-Likelihood:                 776.74
# No. Observations:                4713   AIC:                            -1549.
# Df Residuals:                    4711   BIC:                            -1537.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6169      0.004    151.601      0.000       0.609       0.625
# PPTUG_EF      -0.0605      0.012     -4.840      0.000      -0.085      -0.036
# ==============================================================================
# Omnibus:                      980.238   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              193.620
# Skew:                          -0.069   Prob(JB):                     9.04e-43
# Kurtosis:                       2.017   Cond. No.                         4.39
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 15
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     3507.
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:30:15   Log-Likelihood:                 2076.0
# No. Observations:                4703   AIC:                            -4148.
# Df Residuals:                    4701   BIC:                            -4135.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9408      0.006    153.609      0.000       0.929       0.953
# PCTPELL       -0.6337      0.011    -59.217      0.000      -0.655      -0.613
# ==============================================================================
# Omnibus:                      116.194   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.929
# Skew:                          -0.383   Prob(JB):                     7.45e-28
# Kurtosis:                       3.226   Cond. No.                         6.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 16
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     85.19
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           4.01e-20
# Time:                        23:30:15   Log-Likelihood:                 807.81
# No. Observations:                4703   AIC:                            -1612.
# Df Residuals:                    4701   BIC:                            -1599.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6742      0.008     82.509      0.000       0.658       0.690
# PCTFLOAN      -0.1172      0.013     -9.230      0.000      -0.142      -0.092
# ==============================================================================
# Omnibus:                      922.039   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              185.629
# Skew:                           0.016   Prob(JB):                     4.91e-41
# Kurtosis:                       2.027   Cond. No.                         5.87
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 17
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     1713.
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):          1.21e-319
# Time:                        23:30:15   Log-Likelihood:                 1496.0
# No. Observations:                4710   AIC:                            -2988.
# Df Residuals:                    4708   BIC:                            -2975.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7954      0.005    150.052      0.000       0.785       0.806
# UG25abv       -0.4649      0.011    -41.391      0.000      -0.487      -0.443
# ==============================================================================
# Omnibus:                        2.590   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.274   Jarque-Bera (JB):                2.479
# Skew:                          -0.016   Prob(JB):                        0.290
# Kurtosis:                       2.892   Cond. No.                         5.16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 18
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     163.5
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           7.57e-37
# Time:                        23:30:15   Log-Likelihood:                 858.02
# No. Observations:                4837   AIC:                            -1712.
# Df Residuals:                    4835   BIC:                            -1699.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.5254      0.006     80.840      0.000       0.513       0.538
# GRAD_DEBT_MDN_SUPP  4.249e-06   3.32e-07     12.787      0.000     3.6e-06     4.9e-06
# ==============================================================================
# Omnibus:                     1254.539   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              216.777
# Skew:                          -0.081   Prob(JB):                     8.46e-48
# Kurtosis:                       1.976   Cond. No.                     4.36e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.36e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 19
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     163.5
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           7.57e-37
# Time:                        23:30:15   Log-Likelihood:                 858.02
# No. Observations:                4837   AIC:                            -1712.
# Df Residuals:                    4835   BIC:                            -1699.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.5254      0.006     80.840      0.000       0.513       0.538
# GRAD_DEBT_MDN10YR_SUPP     0.0004   2.99e-05     12.787      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                     1254.539   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              216.777
# Skew:                          -0.081   Prob(JB):                     8.46e-48
# Kurtosis:                       1.976   Cond. No.                         484.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 20
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     78.87
# Date:                Tue, 13 Mar 2018   Prob (F-statistic):           9.40e-19
# Time:                        23:30:15   Log-Likelihood:                 813.60
# No. Observations:                4502   AIC:                            -1623.
# Df Residuals:                    4500   BIC:                            -1610.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5372      0.008     70.729      0.000       0.522       0.552
# NET_COST    3.691e-06   4.16e-07      8.881      0.000    2.88e-06    4.51e-06
# ==============================================================================
# Omnibus:                     1011.397   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              197.467
# Skew:                          -0.122   Prob(JB):                     1.32e-43
# Kurtosis:                       2.003   Cond. No.                     4.61e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.61e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#correlations for md_earn_wne_p10
for i in range(len(keep_variables)):
    print str(keep_variables[i])
    print df['md_earn_wne_p10'].corr(df[str(keep_variables[i])])
# Out:
# PREDDEG
# 0.5101550825662963
# CONTROL
# -0.22007578270050793
# LOCALE
# -0.05925531364883557
# DISTANCEONLY
# 0.02792621737271221
# UGDS
# 0.25358793824568443
# UGDS_WHITE
# 0.17887561005004893
# UGDS_BLACK
# -0.17555607159687445
# UGDS_HISP
# -0.2080583557348336
# UGDS_ASIAN
# 0.26623181210731056
# UGDS_AIAN
# -0.0965223412798974
# UGDS_NHPI
# -0.023830632939586396
# UGDS_2MOR
# 0.10605699148847336
# UGDS_NRA
# 0.34719850930673124
# UGDS_UNKN
# 0.10579390976534873
# PPTUG_EF
# -0.062177027658705204
# PCTPELL
# -0.4920656293736687
# PCTFLOAN
# 0.13833720873966204
# UG25abv
# -0.19786941234180655
# GRAD_DEBT_MDN_SUPP
# 0.47209918737640305
# GRAD_DEBT_MDN10YR_SUPP
# 0.47209918736652356
# NET_COST
# 0.3641233990100078

# %%
#regressions for md_earn_wne_p10
for i in range(len(keep_variables)):
    print (i)
    #df[str(treatment_variables[i])]= df[str(treatment_variables[i])].fillna(np.nanmedian(df[str(treatment_variables[i])]))
    print (smf.ols('md_earn_wne_p10 ~ ' + str(keep_variables[i]), data=df).fit().summary())
# Out:
# 0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.260
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     1588.
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):          7.60e-298
# Time:                        00:31:32   Log-Likelihood:                -48864.
# No. Observations:                4516   AIC:                         9.773e+04
# Df Residuals:                    4514   BIC:                         9.775e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.886e+04    404.054     46.680      0.000    1.81e+04    1.97e+04
# PREDDEG     7578.1133    190.160     39.851      0.000    7205.307    7950.919
# ==============================================================================
# Omnibus:                     3914.232   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           271630.887
# Skew:                           3.773   Prob(JB):                         0.00
# Kurtosis:                      40.237   Cond. No.                         5.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     229.8
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           1.17e-50
# Time:                        00:31:32   Log-Likelihood:                -49433.
# No. Observations:                4516   AIC:                         9.887e+04
# Df Residuals:                    4514   BIC:                         9.888e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.087e+04    540.917     75.549      0.000    3.98e+04    4.19e+04
# CONTROL    -3604.9934    237.832    -15.158      0.000   -4071.261   -3138.725
# ==============================================================================
# Omnibus:                     3630.433   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           195939.452
# Skew:                           3.421   Prob(JB):                         0.00
# Kurtosis:                      34.536   Cond. No.                         7.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     15.21
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           9.78e-05
# Time:                        00:31:32   Log-Likelihood:                -47372.
# No. Observations:                4318   AIC:                         9.475e+04
# Df Residuals:                    4316   BIC:                         9.476e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.493e+04    495.688     70.472      0.000     3.4e+04    3.59e+04
# LOCALE       -88.0126     22.569     -3.900      0.000    -132.260     -43.766
# ==============================================================================
# Omnibus:                     3403.898   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           181346.050
# Skew:                           3.316   Prob(JB):                         0.00
# Kurtosis:                      34.048   Cond. No.                         50.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     3.370
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):             0.0665
# Time:                        00:31:32   Log-Likelihood:                -47400.
# No. Observations:                4320   AIC:                         9.480e+04
# Df Residuals:                    4318   BIC:                         9.482e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     3.316e+04    214.761    154.405      0.000    3.27e+04    3.36e+04
# DISTANCEONLY  6925.5657   3772.527      1.836      0.066    -470.525    1.43e+04
# ==============================================================================
# Omnibus:                     3412.743   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           178938.855
# Skew:                           3.333   Prob(JB):                         0.00
# Kurtosis:                      33.817   Cond. No.                         17.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 4
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     293.9
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           9.21e-64
# Time:                        00:31:32   Log-Likelihood:                -46124.
# No. Observations:                4278   AIC:                         9.225e+04
# Df Residuals:                    4276   BIC:                         9.227e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.104e+04    201.543    154.021      0.000    3.06e+04    3.14e+04
# UGDS           0.5534      0.032     17.143      0.000       0.490       0.617
# ==============================================================================
# Omnibus:                     1149.446   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4021.789
# Skew:                           1.321   Prob(JB):                         0.00
# Kurtosis:                       6.948   Cond. No.                     7.06e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 5
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     141.3
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           4.32e-32
# Time:                        00:31:32   Log-Likelihood:                -46197.
# No. Observations:                4278   AIC:                         9.240e+04
# Df Residuals:                    4276   BIC:                         9.241e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.864e+04    383.863     74.598      0.000    2.79e+04    2.94e+04
# UGDS_WHITE  7851.4911    660.421     11.889      0.000    6556.724    9146.258
# ==============================================================================
# Omnibus:                     1043.570   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3387.729
# Skew:                           1.223   Prob(JB):                         0.00
# Kurtosis:                       6.609   Cond. No.                         4.66
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     136.0
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           5.91e-31
# Time:                        00:31:32   Log-Likelihood:                -46199.
# No. Observations:                4278   AIC:                         9.240e+04
# Df Residuals:                    4276   BIC:                         9.242e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    3.45e+04    240.585    143.415      0.000     3.4e+04     3.5e+04
# UGDS_BLACK -9862.0855    845.739    -11.661      0.000   -1.15e+04   -8203.998
# ==============================================================================
# Omnibus:                      921.867   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2750.816
# Skew:                           1.109   Prob(JB):                         0.00
# Kurtosis:                       6.242   Cond. No.                         4.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 7
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     193.5
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           4.74e-43
# Time:                        00:31:32   Log-Likelihood:                -46172.
# No. Observations:                4278   AIC:                         9.235e+04
# Df Residuals:                    4276   BIC:                         9.236e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.447e+04    222.301    155.067      0.000     3.4e+04    3.49e+04
# UGDS_HISP  -1.167e+04    839.275    -13.910      0.000   -1.33e+04      -1e+04
# ==============================================================================
# Omnibus:                      974.694   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3012.346
# Skew:                           1.159   Prob(JB):                         0.00
# Kurtosis:                       6.395   Cond. No.                         4.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 8
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     326.2
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           2.50e-70
# Time:                        00:31:32   Log-Likelihood:                -46109.
# No. Observations:                4278   AIC:                         9.222e+04
# Df Residuals:                    4276   BIC:                         9.223e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.095e+04    201.113    153.896      0.000    3.06e+04    3.13e+04
# UGDS_ASIAN  5.563e+04   3079.967     18.061      0.000    4.96e+04    6.17e+04
# ==============================================================================
# Omnibus:                      610.033   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1910.269
# Skew:                           0.733   Prob(JB):                         0.00
# Kurtosis:                       5.927   Cond. No.                         17.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 9
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     40.21
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           2.51e-10
# Time:                        00:31:32   Log-Likelihood:                -46246.
# No. Observations:                4278   AIC:                         9.250e+04
# Df Residuals:                    4276   BIC:                         9.251e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    3.29e+04    187.012    175.898      0.000    3.25e+04    3.33e+04
# UGDS_AIAN  -1.736e+04   2737.480     -6.341      0.000   -2.27e+04    -1.2e+04
# ==============================================================================
# Omnibus:                      944.163   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2759.937
# Skew:                           1.143   Prob(JB):                         0.00
# Kurtosis:                       6.203   Cond. No.                         14.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 10
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.430
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):              0.119
# Time:                        00:31:32   Log-Likelihood:                -46265.
# No. Observations:                4278   AIC:                         9.253e+04
# Df Residuals:                    4276   BIC:                         9.255e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    3.27e+04    185.813    175.975      0.000    3.23e+04    3.31e+04
# UGDS_NHPI  -8853.2901   5679.720     -1.559      0.119      -2e+04    2281.908
# ==============================================================================
# Omnibus:                      949.474   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2747.820
# Skew:                           1.153   Prob(JB):                         0.00
# Kurtosis:                       6.178   Cond. No.                         30.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 11
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     48.64
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           3.54e-12
# Time:                        00:31:32   Log-Likelihood:                -46242.
# No. Observations:                4278   AIC:                         9.249e+04
# Df Residuals:                    4276   BIC:                         9.250e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.158e+04    239.992    131.574      0.000    3.11e+04     3.2e+04
# UGDS_2MOR   4.607e+04   6605.597      6.975      0.000    3.31e+04     5.9e+04
# ==============================================================================
# Omnibus:                      952.104   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2792.484
# Skew:                           1.151   Prob(JB):                         0.00
# Kurtosis:                       6.220   Cond. No.                         36.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 12
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.121
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     586.1
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):          1.87e-121
# Time:                        00:31:32   Log-Likelihood:                -45992.
# No. Observations:                4278   AIC:                         9.199e+04
# Df Residuals:                    4276   BIC:                         9.200e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.083e+04    188.460    163.594      0.000    3.05e+04    3.12e+04
# UGDS_NRA    1.272e+05   5253.639     24.210      0.000    1.17e+05    1.37e+05
# ==============================================================================
# Omnibus:                      890.076   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3266.248
# Skew:                           1.004   Prob(JB):                         0.00
# Kurtosis:                       6.780   Cond. No.                         30.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 13
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     48.40
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           4.00e-12
# Time:                        00:31:32   Log-Likelihood:                -46242.
# No. Observations:                4278   AIC:                         9.249e+04
# Df Residuals:                    4276   BIC:                         9.250e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.199e+04    206.731    154.747      0.000    3.16e+04    3.24e+04
# UGDS_UNKN   1.158e+04   1664.631      6.957      0.000    8317.342    1.48e+04
# ==============================================================================
# Omnibus:                      958.369   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2811.032
# Skew:                           1.158   Prob(JB):                         0.00
# Kurtosis:                       6.226   Cond. No.                         9.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 14
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     16.58
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           4.76e-05
# Time:                        00:31:32   Log-Likelihood:                -46183.
# No. Observations:                4273   AIC:                         9.237e+04
# Df Residuals:                    4271   BIC:                         9.238e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.338e+04    256.605    130.097      0.000    3.29e+04    3.39e+04
# PPTUG_EF   -3159.9318    776.143     -4.071      0.000   -4681.576   -1638.288
# ==============================================================================
# Omnibus:                      846.004   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2220.896
# Skew:                           1.066   Prob(JB):                         0.00
# Kurtosis:                       5.816   Cond. No.                         4.48
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 15
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.242
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     1366.
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):          1.07e-259
# Time:                        00:31:32   Log-Likelihood:                -45641.
# No. Observations:                4277   AIC:                         9.129e+04
# Df Residuals:                    4275   BIC:                         9.130e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.693e+04    418.263    112.199      0.000    4.61e+04    4.77e+04
# PCTPELL    -2.738e+04    740.766    -36.957      0.000   -2.88e+04   -2.59e+04
# ==============================================================================
# Omnibus:                      813.966   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2545.951
# Skew:                           0.968   Prob(JB):                         0.00
# Kurtosis:                       6.246   Cond. No.                         5.96
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 16
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     83.41
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           1.01e-19
# Time:                        00:31:32   Log-Likelihood:                -46193.
# No. Observations:                4277   AIC:                         9.239e+04
# Df Residuals:                    4275   BIC:                         9.240e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.934e+04    404.695     72.488      0.000    2.85e+04    3.01e+04
# PCTFLOAN    6073.9237    665.069      9.133      0.000    4770.044    7377.803
# ==============================================================================
# Omnibus:                      910.670   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2542.100
# Skew:                           1.120   Prob(JB):                         0.00
# Kurtosis:                       6.041   Cond. No.                         4.81
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 17
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     173.8
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):           6.29e-39
# Time:                        00:31:32   Log-Likelihood:                -46052.
# No. Observations:                4267   AIC:                         9.211e+04
# Df Residuals:                    4265   BIC:                         9.212e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.684e+04    364.321    101.120      0.000    3.61e+04    3.76e+04
# UG25abv    -1.054e+04    799.230    -13.183      0.000   -1.21e+04   -8969.263
# ==============================================================================
# Omnibus:                     1006.440   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3226.800
# Skew:                           1.186   Prob(JB):                         0.00
# Kurtosis:                       6.538   Cond. No.                         5.16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 18
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.223
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     1166.
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):          6.96e-225
# Time:                        00:31:32   Log-Likelihood:                -43728.
# No. Observations:                4067   AIC:                         8.746e+04
# Df Residuals:                    4065   BIC:                         8.747e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           2.133e+04    409.099     52.146      0.000    2.05e+04    2.21e+04
# GRAD_DEBT_MDN_SUPP     0.7006      0.021     34.144      0.000       0.660       0.741
# ==============================================================================
# Omnibus:                     3095.099   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           168739.546
# Skew:                           3.121   Prob(JB):                         0.00
# Kurtosis:                      33.932   Cond. No.                     4.60e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 19
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.223
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     1166.
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):          6.96e-225
# Time:                        00:31:32   Log-Likelihood:                -43728.
# No. Observations:                4067   AIC:                         8.746e+04
# Df Residuals:                    4065   BIC:                         8.747e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               2.133e+04    409.099     52.146      0.000    2.05e+04    2.21e+04
# GRAD_DEBT_MDN10YR_SUPP    63.1075      1.848     34.144      0.000      59.484      66.731
# ==============================================================================
# Omnibus:                     3095.099   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           168739.546
# Skew:                           3.121   Prob(JB):                         0.00
# Kurtosis:                      33.932   Cond. No.                         511.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 20
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     630.8
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):          1.15e-129
# Time:                        00:31:32   Log-Likelihood:                -44170.
# No. Observations:                4129   AIC:                         8.834e+04
# Df Residuals:                    4127   BIC:                         8.836e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.337e+04    390.297     59.872      0.000    2.26e+04    2.41e+04
# NET_COST       0.5502      0.022     25.116      0.000       0.507       0.593
# ==============================================================================
# Omnibus:                      396.751   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              678.966
# Skew:                           0.678   Prob(JB):                    3.67e-148
# Kurtosis:                       4.451   Cond. No.                     4.17e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.17e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#correlations for '25k_or_above'
for i in range(len(keep_variables)):
    print str(keep_variables[i])
    print df['Binary_25k'].corr(df[str(keep_variables[i])])
# Out:
# PREDDEG
# 0.4452066552482802
# CONTROL
# -0.19929842270580875
# LOCALE
# -0.040100734974154416
# DISTANCEONLY
# 0.042130144340041316
# UGDS
# 0.20306269484199088
# UGDS_WHITE
# 0.2040143509457409
# UGDS_BLACK
# -0.18214211955395804
# UGDS_HISP
# -0.16980338843806422
# UGDS_ASIAN
# 0.15279520399252933
# UGDS_AIAN
# -0.0681686151127176
# UGDS_NHPI
# -0.011840816915172537
# UGDS_2MOR
# 0.044022943449649694
# UGDS_NRA
# 0.2622331998588809
# UGDS_UNKN
# 0.052629798354172586
# PPTUG_EF
# -0.1012433905694558
# PCTPELL
# -0.41890471591746165
# PCTFLOAN
# 0.13848934828092432
# UG25abv
# -0.21095094479651527
# GRAD_DEBT_MDN_SUPP
# 0.42761001057981113
# GRAD_DEBT_MDN10YR_SUPP
# 0.4276100105715761
# NET_COST
# 0.2881464410270117

# %%
#regressions for 25k_or_above
for i in range(len(keep_variables)):
    print (i)
    #if i==3:
       # next
    
    print (smf.logit('Binary_25k ~ ' + str(keep_variables[i]), data=df).fit().summary())
# Out:
# 0
# Optimization terminated successfully.
#          Current function value: 0.508251
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4751
# Model:                          Logit   Df Residuals:                     4749
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                  0.1741
# Time:                        01:08:16   Log-Likelihood:                -2414.7
# converged:                       True   LL-Null:                       -2923.7
#                                         LLR p-value:                2.279e-223
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.3018      0.102    -32.512      0.000      -3.501      -3.103
# PREDDEG        1.1987      0.042     28.279      0.000       1.116       1.282
# ==============================================================================
# 1
# Optimization terminated successfully.
#          Current function value: 0.595538
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4751
# Model:                          Logit   Df Residuals:                     4749
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.03224
# Time:                        01:08:17   Log-Likelihood:                -2829.4
# converged:                       True   LL-Null:                       -2923.7
#                                         LLR p-value:                 6.679e-43
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2194      0.081      2.713      0.007       0.061       0.378
# CONTROL       -0.5059      0.037    -13.561      0.000      -0.579      -0.433
# ==============================================================================
# 2
# Optimization terminated successfully.
#          Current function value: 0.610106
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4549
# Model:                          Logit   Df Residuals:                     4547
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                0.001333
# Time:                        01:08:17   Log-Likelihood:                -2775.4
# converged:                       True   LL-Null:                       -2779.1
#                                         LLR p-value:                  0.006498
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6618      0.075     -8.794      0.000      -0.809      -0.514
# LOCALE        -0.0095      0.003     -2.702      0.007      -0.016      -0.003
# ==============================================================================
# 3
# Optimization terminated successfully.
#          Current function value: 0.610071
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4550
# Model:                          Logit   Df Residuals:                     4548
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                0.001298
# Time:                        01:08:17   Log-Likelihood:                -2775.8
# converged:                       True   LL-Null:                       -2779.4
#                                         LLR p-value:                  0.007218
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.8528      0.032    -26.285      0.000      -0.916      -0.789
# DISTANCEONLY     1.3636      0.517      2.635      0.008       0.349       2.378
# ================================================================================
# 4
# Optimization terminated successfully.
#          Current function value: 0.586022
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.03154
# Time:                        01:08:17   Log-Likelihood:                -2637.1
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                 3.014e-39
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.1152      0.039    -28.903      0.000      -1.191      -1.040
# UGDS        7.782e-05   6.38e-06     12.202      0.000    6.53e-05    9.03e-05
# ==============================================================================
# 5
# Optimization terminated successfully.
#          Current function value: 0.583489
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.03573
# Time:                        01:08:17   Log-Likelihood:                -2625.7
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                 3.180e-44
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.8179      0.081    -22.526      0.000      -1.976      -1.660
# UGDS_WHITE     1.7376      0.129     13.429      0.000       1.484       1.991
# ==============================================================================
# 6
# Optimization terminated successfully.
#          Current function value: 0.585862
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.03181
# Time:                        01:08:17   Log-Likelihood:                -2636.4
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                 1.464e-39
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4854      0.044    -10.999      0.000      -0.572      -0.399
# UGDS_BLACK    -2.4041      0.205    -11.724      0.000      -2.806      -2.002
# ==============================================================================
# 7
# Optimization terminated successfully.
#          Current function value: 0.587598
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.02894
# Time:                        01:08:17   Log-Likelihood:                -2644.2
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                 3.777e-36
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5607      0.041    -13.541      0.000      -0.642      -0.480
# UGDS_HISP     -2.3987      0.223    -10.765      0.000      -2.835      -1.962
# ==============================================================================
# 8
# Optimization terminated successfully.
#          Current function value: 0.594041
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.01829
# Time:                        01:08:17   Log-Likelihood:                -2673.2
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                 1.854e-23
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0623      0.039    -27.476      0.000      -1.138      -0.987
# UGDS_ASIAN     5.6666      0.620      9.133      0.000       4.450       6.883
# ==============================================================================
# 9
# Optimization terminated successfully.
#          Current function value: 0.600260
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                0.008015
# Time:                        01:08:17   Log-Likelihood:                -2701.2
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                 3.930e-11
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7980      0.036    -22.183      0.000      -0.868      -0.727
# UGDS_AIAN     -9.5488      2.173     -4.395      0.000     -13.807      -5.290
# ==============================================================================
# 10
# Optimization terminated successfully.
#          Current function value: 0.605030
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:               0.0001304
# Time:                        01:08:17   Log-Likelihood:                -2722.6
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                    0.3995
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8748      0.033    -26.349      0.000      -0.940      -0.810
# UGDS_NHPI     -1.1269      1.450     -0.777      0.437      -3.969       1.715
# ==============================================================================
# 11
# Optimization terminated successfully.
#          Current function value: 0.604178
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                0.001539
# Time:                        01:08:17   Log-Likelihood:                -2718.8
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                  0.003791
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9575      0.043    -22.457      0.000      -1.041      -0.874
# UGDS_2MOR      3.3043      1.133      2.917      0.004       1.084       5.524
# ==============================================================================
# 12
# Optimization terminated successfully.
#          Current function value: 0.570456
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.05727
# Time:                        01:08:17   Log-Likelihood:                -2567.1
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                 8.521e-70
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.1735      0.039    -30.388      0.000      -1.249      -1.098
# UGDS_NRA      20.1034      1.339     15.019      0.000      17.480      22.727
# ==============================================================================
# 13
# Optimization terminated successfully.
#          Current function value: 0.603791
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4500
# Model:                          Logit   Df Residuals:                     4498
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                0.002179
# Time:                        01:08:17   Log-Likelihood:                -2717.1
# converged:                       True   LL-Null:                       -2723.0
#                                         LLR p-value:                 0.0005723
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9372      0.037    -25.343      0.000      -1.010      -0.865
# UGDS_UNKN      0.9829      0.281      3.496      0.000       0.432       1.534
# ==============================================================================
# 14
# Optimization terminated successfully.
#          Current function value: 0.599771
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4497
# Model:                          Logit   Df Residuals:                     4495
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                0.008783
# Time:                        01:08:17   Log-Likelihood:                -2697.2
# converged:                       True   LL-Null:                       -2721.1
#                                         LLR p-value:                 4.719e-12
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6642      0.045    -14.887      0.000      -0.752      -0.577
# PPTUG_EF      -0.9896      0.147     -6.746      0.000      -1.277      -0.702
# ==============================================================================
# 15
# Optimization terminated successfully.
#          Current function value: 0.507859
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4499
# Model:                          Logit   Df Residuals:                     4497
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                  0.1605
# Time:                        01:08:17   Log-Likelihood:                -2284.9
# converged:                       True   LL-Null:                       -2721.8
#                                         LLR p-value:                4.834e-192
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6285      0.097     16.809      0.000       1.439       1.818
# PCTPELL       -5.2405      0.204    -25.681      0.000      -5.640      -4.841
# ==============================================================================
# 16
# Optimization terminated successfully.
#          Current function value: 0.595029
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4499
# Model:                          Logit   Df Residuals:                     4497
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.01643
# Time:                        01:08:17   Log-Likelihood:                -2677.0
# converged:                       True   LL-Null:                       -2721.8
#                                         LLR p-value:                 3.135e-21
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.5498      0.082    -18.853      0.000      -1.711      -1.389
# PCTFLOAN       1.1866      0.129      9.196      0.000       0.934       1.440
# ==============================================================================
# 17
# Optimization terminated successfully.
#          Current function value: 0.582237
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4489
# Model:                          Logit   Df Residuals:                     4487
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.03787
# Time:                        01:08:17   Log-Likelihood:                -2613.7
# converged:                       True   LL-Null:                       -2716.5
#                                         LLR p-value:                 1.162e-46
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0550      0.065     -0.843      0.399      -0.183       0.073
# UG25abv       -2.1785      0.157    -13.862      0.000      -2.486      -1.870
# ==============================================================================
# 18
# Optimization terminated successfully.
#          Current function value: 0.538875
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4273
# Model:                          Logit   Df Residuals:                     4271
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                  0.1498
# Time:                        01:08:17   Log-Likelihood:                -2302.6
# converged:                       True   LL-Null:                       -2708.4
#                                         LLR p-value:                1.707e-178
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -2.9207      0.097    -29.984      0.000      -3.112      -2.730
# GRAD_DEBT_MDN_SUPP     0.0001   4.57e-06     25.623      0.000       0.000       0.000
# ======================================================================================
# 19
# Optimization terminated successfully.
#          Current function value: 0.538875
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4273
# Model:                          Logit   Df Residuals:                     4271
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                  0.1498
# Time:                        01:08:17   Log-Likelihood:                -2302.6
# converged:                       True   LL-Null:                       -2708.4
#                                         LLR p-value:                1.707e-178
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -2.9207      0.097    -29.984      0.000      -3.112      -2.730
# GRAD_DEBT_MDN10YR_SUPP     0.0105      0.000     25.623      0.000       0.010       0.011
# ==========================================================================================
# 20
# Optimization terminated successfully.
#          Current function value: 0.550826
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 4329
# Model:                          Logit   Df Residuals:                     4327
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                 0.07100
# Time:                        01:08:17   Log-Likelihood:                -2384.5
# converged:                       True   LL-Null:                       -2566.8
#                                         LLR p-value:                 2.938e-81
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.4607      0.095    -25.837      0.000      -2.647      -2.274
# NET_COST     8.88e-05   4.94e-06     17.988      0.000    7.91e-05    9.85e-05
# ==============================================================================

# %%
total = ''
for i in range(len(keep_variables)):
    if i== len(keep_variables)-1:
        total = total + str(keep_variables[i])
    elif str(keep_variables[i]) == 'GRAD_DEBT_MDN10YR_SUPP':
        next
    elif str(keep_variables[i]) == 'UGDS_UNKN':
        next
    else:
        total = total + str(keep_variables[i]) + ' + '

# %%
total
# Out:
# 'PREDDEG + CONTROL + LOCALE + DISTANCEONLY + UGDS + UGDS_WHITE + UGDS_BLACK + UGDS_HISP + UGDS_ASIAN + UGDS_AIAN + UGDS_NHPI + UGDS_2MOR + UGDS_NRA + PPTUG_EF + PCTPELL + PCTFLOAN + UG25abv + GRAD_DEBT_MDN_SUPP + NET_COST'

# %%
smf.ols('RPY_3YR_RT_SUPP ~ ' + total, data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RPY_3YR_RT_SUPP   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     506.9
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):               0.00
# Time:                        00:02:11   Log-Likelihood:                 3261.9
# No. Observations:                4309   AIC:                            -6484.
# Df Residuals:                    4289   BIC:                            -6356.
# Df Model:                          19
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.6895      0.023     30.417      0.000       0.645       0.734
# PREDDEG                0.0501      0.004     13.376      0.000       0.043       0.057
# CONTROL               -0.0386      0.004    -10.878      0.000      -0.046      -0.032
# LOCALE                -0.0004      0.000     -1.562      0.118      -0.001    8.95e-05
# DISTANCEONLY           0.0470      0.029      1.616      0.106      -0.010       0.104
# UGDS               -1.827e-06   4.01e-07     -4.555      0.000   -2.61e-06   -1.04e-06
# UGDS_WHITE             0.1419      0.017      8.228      0.000       0.108       0.176
# UGDS_BLACK            -0.0911      0.018     -4.979      0.000      -0.127      -0.055
# UGDS_HISP              0.0755      0.019      3.969      0.000       0.038       0.113
# UGDS_ASIAN             0.6097      0.042     14.668      0.000       0.528       0.691
# UGDS_AIAN             -0.1801      0.058     -3.096      0.002      -0.294      -0.066
# UGDS_NHPI             -0.3818      0.113     -3.371      0.001      -0.604      -0.160
# UGDS_2MOR              0.0652      0.068      0.955      0.340      -0.069       0.199
# UGDS_NRA               0.3727      0.065      5.724      0.000       0.245       0.500
# PPTUG_EF              -0.0138      0.009     -1.486      0.137      -0.032       0.004
# PCTPELL               -0.4972      0.015    -32.472      0.000      -0.527      -0.467
# PCTFLOAN               0.3188      0.014     23.618      0.000       0.292       0.345
# UG25abv               -0.1275      0.011    -11.565      0.000      -0.149      -0.106
# GRAD_DEBT_MDN_SUPP -3.787e-06   3.67e-07    -10.312      0.000   -4.51e-06   -3.07e-06
# NET_COST            9.652e-07    3.5e-07      2.754      0.006    2.78e-07    1.65e-06
# ==============================================================================
# Omnibus:                      100.619   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              208.880
# Skew:                           0.114   Prob(JB):                     4.39e-46
# Kurtosis:                       4.054   Cond. No.                     1.71e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.71e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
smf.ols('md_earn_wne_p10 ~ ' + total, data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.614
# Model:                            OLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     309.8
# Date:                Wed, 14 Mar 2018   Prob (F-statistic):               0.00
# Time:                        00:41:20   Log-Likelihood:                -38229.
# No. Observations:                3715   AIC:                         7.650e+04
# Df Residuals:                    3695   BIC:                         7.662e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           3.105e+04   1511.563     20.539      0.000    2.81e+04     3.4e+04
# PREDDEG             2964.6486    268.376     11.047      0.000    2438.469    3490.828
# CONTROL            -3596.6051    254.718    -14.120      0.000   -4096.006   -3097.204
# LOCALE                -6.1651     14.996     -0.411      0.681     -35.566      23.235
# DISTANCEONLY        -732.3928   2412.284     -0.304      0.761   -5461.932    3997.147
# UGDS                   0.0938      0.026      3.619      0.000       0.043       0.145
# UGDS_WHITE         -4318.1573   1149.447     -3.757      0.000   -6571.769   -2064.545
# UGDS_BLACK         -4092.5076   1219.598     -3.356      0.001   -6483.659   -1701.356
# UGDS_HISP          -2390.8269   1275.228     -1.875      0.061   -4891.047     109.393
# UGDS_ASIAN          4.308e+04   2960.413     14.553      0.000    3.73e+04    4.89e+04
# UGDS_AIAN          -7760.8785   3955.721     -1.962      0.050   -1.55e+04      -5.268
# UGDS_NHPI          -1.983e+04   7153.364     -2.773      0.006   -3.39e+04   -5809.204
# UGDS_2MOR          -6417.4897   4697.793     -1.366      0.172   -1.56e+04    2793.032
# UGDS_NRA           -1574.0851   4458.605     -0.353      0.724   -1.03e+04    7167.484
# PPTUG_EF           -4923.8499    663.643     -7.419      0.000   -6224.992   -3622.708
# PCTPELL            -2.098e+04   1048.829    -20.008      0.000    -2.3e+04   -1.89e+04
# PCTFLOAN            7028.4028    929.103      7.565      0.000    5206.798    8850.007
# UG25abv             1.036e+04    770.125     13.457      0.000    8853.935    1.19e+04
# GRAD_DEBT_MDN_SUPP     0.2595      0.027      9.729      0.000       0.207       0.312
# NET_COST               0.3161      0.025     12.778      0.000       0.268       0.365
# ==============================================================================
# Omnibus:                      826.448   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4642.571
# Skew:                           0.941   Prob(JB):                         0.00
# Kurtosis:                       8.143   Cond. No.                     1.62e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.62e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
smf.logit('Binary_25k ~ ' + total , data=df).fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.340499
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Binary_25k   No. Observations:                 3896
# Model:                          Logit   Df Residuals:                     3876
# Method:                           MLE   Df Model:                           19
# Date:                Wed, 14 Mar 2018   Pseudo R-squ.:                  0.4475
# Time:                        01:16:36   Log-Likelihood:                -1326.6
# converged:                       True   LL-Null:                       -2400.9
#                                         LLR p-value:                     0.000
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -1.5983      0.639     -2.501      0.012      -2.851      -0.346
# PREDDEG                0.8133      0.114      7.143      0.000       0.590       1.036
# CONTROL               -1.1036      0.107    -10.287      0.000      -1.314      -0.893
# LOCALE                -0.0020      0.006     -0.334      0.738      -0.014       0.010
# DISTANCEONLY           0.6921      0.752      0.920      0.357      -0.782       2.166
# UGDS                2.951e-05   1.03e-05      2.860      0.004    9.29e-06    4.97e-05
# UGDS_WHITE            -0.0895      0.480     -0.186      0.852      -1.030       0.851
# UGDS_BLACK            -0.1907      0.521     -0.366      0.714      -1.212       0.831
# UGDS_HISP              0.5148      0.591      0.871      0.384      -0.643       1.673
# UGDS_ASIAN             8.3411      1.271      6.561      0.000       5.849      10.833
# UGDS_AIAN             -9.9573      3.849     -2.587      0.010     -17.502      -2.413
# UGDS_NHPI              3.2040      2.909      1.101      0.271      -2.497       8.905
# UGDS_2MOR             -4.1091      2.101     -1.956      0.050      -8.226       0.008
# UGDS_NRA              -3.7994      1.596     -2.381      0.017      -6.927      -0.672
# PPTUG_EF              -1.9268      0.277     -6.954      0.000      -2.470      -1.384
# PCTPELL               -9.9747      0.567    -17.591      0.000     -11.086      -8.863
# PCTFLOAN               5.9576      0.453     13.152      0.000       5.070       6.845
# UG25abv                4.3175      0.343     12.580      0.000       3.645       4.990
# GRAD_DEBT_MDN_SUPP  2.313e-05    1.1e-05      2.103      0.035    1.57e-06    4.47e-05
# NET_COST            4.038e-05   1.09e-05      3.713      0.000    1.91e-05    6.17e-05
# ======================================================================================
# """

# %%
repay_pvalues = smf.ols('RPY_3YR_RT_SUPP ~ ' + total, data=df).fit().pvalues
smr.sandbox.stats.multicomp.multipletests(repay_pvalues, alpha=0.05, method='bonferroni')
# Out:
# (array([ True,  True,  True, False, False,  True,  True,  True,  True,
#          True,  True,  True, False,  True, False,  True,  True,  True,
#          True, False]),
#  array([6.89095043e-183, 1.05016097e-038, 6.64629893e-026, 1.00000000e+000,
#         1.00000000e+000, 1.07833305e-004, 5.00656853e-015, 1.32838607e-005,
#         1.46626621e-003, 2.87482030e-046, 3.94219369e-002, 1.50950035e-002,
#         1.00000000e+000, 2.21730770e-007, 1.00000000e+000, 1.04233204e-205,
#         9.69054131e-115, 3.51031640e-029, 2.40212562e-023, 1.18174934e-001]),
#  0.0025613787765302876,
#  0.0025)

# %%
median_pvalues = smf.ols('md_earn_wne_p10 ~ ' + total, data=df).fit().pvalues
smr.sandbox.stats.multicomp.multipletests(median_pvalues, alpha=0.05, method='bonferroni')
# Out:
# (array([ True,  True,  True, False, False,  True,  True,  True, False,
#          True, False, False, False, False,  True,  True,  True,  True,
#          True,  True]),
#  array([1.49789480e-87, 1.23987422e-26, 7.88226471e-43, 1.00000000e+00,
#         1.00000000e+00, 5.99476244e-03, 3.49610296e-03, 1.59973475e-02,
#         1.00000000e+00, 2.14036739e-45, 9.96893226e-01, 1.11744054e-01,
#         1.00000000e+00, 1.00000000e+00, 2.90329212e-12, 2.45463957e-83,
#         9.75423889e-13, 4.89680626e-39, 8.32523934e-21, 2.56939242e-35]),
#  0.0025613787765302876,
#  0.0025)

# %%
binary_pvalues = smf.logit('Binary_25k ~ ' + total , data=df).fit().pvalues
smr.sandbox.stats.multicomp.multipletests(binary_pvalues, alpha=0.05, method='bonferroni')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.340499
#          Iterations 8
# (array([False,  True,  True, False, False, False, False, False, False,
#          True, False, False, False, False,  True,  True,  True,  True,
#         False,  True]),
#  array([2.48012332e-01, 1.82031023e-11, 1.60814675e-23, 1.00000000e+00,
#         1.00000000e+00, 8.46119898e-02, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.07076078e-09, 1.93755212e-01, 1.00000000e+00,
#         1.00000000e+00, 3.45210581e-01, 7.12572025e-11, 5.80470567e-68,
#         3.31029949e-38, 5.46968382e-35, 7.09250839e-01, 4.08932722e-03]),
#  0.0025613787765302876,
#  0.0025)

# %%
binary_pvalues
# Out:
# Intercept             1.240062e-02
# PREDDEG               9.101551e-13
# CONTROL               8.040734e-25
# LOCALE                7.381179e-01
# DISTANCEONLY          3.573423e-01
# UGDS                  4.230599e-03
# UGDS_WHITE            8.521320e-01
# UGDS_BLACK            7.144567e-01
# UGDS_HISP             3.836668e-01
# UGDS_ASIAN            5.353804e-11
# UGDS_AIAN             9.687761e-03
# UGDS_NHPI             2.707143e-01
# UGDS_2MOR             5.045566e-02
# UGDS_NRA              1.726053e-02
# PPTUG_EF              3.562860e-12
# PCTPELL               2.902353e-69
# PCTFLOAN              1.655150e-39
# UG25abv               2.734842e-36
# GRAD_DEBT_MDN_SUPP    3.546254e-02
# NET_COST              2.044664e-04
# dtype: float64
